# %% [markdown]
# # Exploratory Data Analysis(EDA) of Property Data

# %%
# Import required libraries for EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings

# %%
# Code to upload the data 
df=pd.read_csv('Property_data.csv')

# %%
# To know the upper five rows of the data
df.head()
# Out:
#    PropertyID  PropertyClass PropertyZone  PropertyFrontage  PropertySize  \
# 0           1             60           RL              65.0          8450
# 1           2             20           RL              80.0          9600
# 2           3             60           RL              68.0         11250
# 3           4             70           RL              60.0          9550
# 4           5             60           RL              84.0         14260
#
#   Street Alley PropertyShape Elevation Amenities  ... PoolArea PoolQC  \
# 0   Pave   NaN           Reg       Lvl    AllPub  ...        0    NaN
# 1   Pave   NaN           Reg       Lvl    AllPub  ...        0    NaN
# 2   Pave   NaN           IR1       Lvl    AllPub  ...        0    NaN
# 3   Pave   NaN           IR1       Lvl    AllPub  ...        0    NaN
# 4   Pave   NaN           IR1       Lvl    AllPub  ...        0    NaN
#
#   BoundaryFeatures AddFeatures AddVal SaleMon SaleYr  SaleType  SaleCondn  \
# 0              NaN         NaN      0       2   2008        WD     Normal
# 1              NaN         NaN      0       5   2007        WD     Normal
# 2              NaN         NaN      0       9   2008        WD     Normal
# 3              NaN         NaN      0       2   2006        WD    Abnorml
# 4              NaN         NaN      0      12   2008        WD     Normal
#
#    PropPrice
# 0     208500
# 1     181500
# 2     223500
# 3     140000
# 4     250000
#
# [5 rows x 81 columns]

# %%
# To know five point summary of each column
df.describe().T
# Out:
#                        count           mean           std      min        25%  \
# PropertyID            1460.0     730.500000    421.610009      1.0     365.75
# PropertyClass         1460.0      56.897260     42.300571     20.0      20.00
# PropertyFrontage      1201.0      70.049958     24.284752     21.0      59.00
# PropertySize          1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual           1460.0       6.099315      1.382997      1.0       5.00
# OverallCond           1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt             1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd          1460.0    1984.865753     20.645407   1950.0    1967.00
# ExteriorCladdingArea  1452.0     103.685262    181.066207      0.0       0.00
# BsmntFinSty1          1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2            1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF             1460.0     567.240411    441.866955      0.0     223.00
# BsmntSqFtage          1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF              1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF              1460.0     346.992466    436.528436      0.0       0.00
# LowQualFinSF          1460.0       5.844521     48.623081      0.0       0.00
# GrLivArea             1460.0    1515.463699    525.480383    334.0    1129.50
# BsmtFullBath          1460.0       0.425342      0.518911      0.0       0.00
# BsmtHalfBath          1460.0       0.057534      0.238753      0.0       0.00
# Bath1                 1460.0       1.565068      0.550916      0.0       1.00
# Bath2                 1460.0       0.382877      0.502885      0.0       0.00
# BedroomUpLev          1460.0       2.866438      0.815778      0.0       2.00
# KitchenUpLev          1460.0       1.046575      0.220338      0.0       1.00
# CntRmsUpLev           1460.0       6.517808      1.625393      2.0       5.00
# CntFireplaces         1460.0       0.613014      0.644666      0.0       0.00
# BasementYrBlt         1379.0    1978.506164     24.689725   1900.0    1961.00
# BasementCars          1460.0       1.767123      0.747315      0.0       1.00
# BasementSqFootage     1460.0     472.980137    213.804841      0.0     334.50
# WoodDeckSF            1460.0      94.244521    125.338794      0.0       0.00
# OpenPorchSF           1460.0      46.660274     66.256028      0.0       0.00
# EnclosedPorch         1460.0      21.954110     61.119149      0.0       0.00
# 3SsnPorch             1460.0       3.409589     29.317331      0.0       0.00
# ScreenPorch           1460.0      15.060959     55.757415      0.0       0.00
# PoolArea              1460.0       2.758904     40.177307      0.0       0.00
# AddVal                1460.0      43.489041    496.123024      0.0       0.00
# SaleMon               1460.0       6.321918      2.703626      1.0       5.00
# SaleYr                1460.0    2007.815753      1.328095   2006.0    2007.00
# PropPrice             1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                            50%        75%       max
# PropertyID               730.5    1095.25    1460.0
# PropertyClass             50.0      70.00     190.0
# PropertyFrontage          69.0      80.00     313.0
# PropertySize            9478.5   11601.50  215245.0
# OverallQual                6.0       7.00      10.0
# OverallCond                5.0       6.00       9.0
# YearBuilt               1973.0    2000.00    2010.0
# YearRemodAdd            1994.0    2004.00    2010.0
# ExteriorCladdingArea       0.0     166.00    1600.0
# BsmntFinSty1             383.5     712.25    5644.0
# BsmtFinSF2                 0.0       0.00    1474.0
# BsmtUnfSF                477.5     808.00    2336.0
# BsmntSqFtage             991.5    1298.25    6110.0
# 1stFlrSF                1087.0    1391.25    4692.0
# 2ndFlrSF                   0.0     728.00    2065.0
# LowQualFinSF               0.0       0.00     572.0
# GrLivArea               1464.0    1776.75    5642.0
# BsmtFullBath               0.0       1.00       3.0
# BsmtHalfBath               0.0       0.00       2.0
# Bath1                      2.0       2.00       3.0
# Bath2                      0.0       1.00       2.0
# BedroomUpLev               3.0       3.00       8.0
# KitchenUpLev               1.0       1.00       3.0
# CntRmsUpLev                6.0       7.00      14.0
# CntFireplaces              1.0       1.00       3.0
# BasementYrBlt           1980.0    2002.00    2010.0
# BasementCars               2.0       2.00       4.0
# BasementSqFootage        480.0     576.00    1418.0
# WoodDeckSF                 0.0     168.00     857.0
# OpenPorchSF               25.0      68.00     547.0
# EnclosedPorch              0.0       0.00     552.0
# 3SsnPorch                  0.0       0.00     508.0
# ScreenPorch                0.0       0.00     480.0
# PoolArea                   0.0       0.00     738.0
# AddVal                     0.0       0.00   15500.0
# SaleMon                    6.0       8.00      12.0
# SaleYr                  2008.0    2009.00    2010.0
# PropPrice             163000.0  214000.00  755000.0

# %%
# To know the data type of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   PropertyID            1460 non-null   int64
#  1   PropertyClass         1460 non-null   int64
#  2   PropertyZone          1460 non-null   object
#  3   PropertyFrontage      1201 non-null   float64
#  4   PropertySize          1460 non-null   int64
#  5   Street                1460 non-null   object
#  6   Alley                 91 non-null     object
#  7   PropertyShape         1460 non-null   object
#  8   Elevation             1460 non-null   object
#  9   Amenities             1460 non-null   object
#  10  Orientation           1460 non-null   object
#  11  Grade                 1460 non-null   object
#  12  Neighborhood          1460 non-null   object
#  13  Condition1            1460 non-null   object
#  14  Condition2            1460 non-null   object
#  15  BldgType              1460 non-null   object
#  16  PropertyStyle         1460 non-null   object
#  17  OverallQual           1460 non-null   int64
#  18  OverallCond           1460 non-null   int64
#  19  YearBuilt             1460 non-null   int64
#  20  YearRemodAdd          1460 non-null   int64
#  21  RoofStyle             1460 non-null   object
#  22  RoofMatl              1460 non-null   object
#  23  Roof1Material         1460 non-null   object
#  24  Roof2Material         1460 non-null   object
#  25  ExteriorCladdingType  588 non-null    object
#  26  ExteriorCladdingArea  1452 non-null   float64
#  27  ExterQual             1460 non-null   object
#  28  ExterCond             1460 non-null   object
#  29  PropertyFooting       1460 non-null   object
#  30  BsmntFinish           1423 non-null   object
#  31  BsmntMaintenance      1423 non-null   object
#  32  BsmntVisibility       1422 non-null   object
#  33  BsmntFinRat1          1423 non-null   object
#  34  BsmntFinSty1          1460 non-null   int64
#  35  BsmntFinQual1         1422 non-null   object
#  36  BsmtFinSF2            1460 non-null   int64
#  37  BsmtUnfSF             1460 non-null   int64
#  38  BsmntSqFtage          1460 non-null   int64
#  39  Heating               1460 non-null   object
#  40  HeatingEfficiency     1460 non-null   object
#  41  CentralAir            1460 non-null   object
#  42  Electrical            1459 non-null   object
#  43  1stFlrSF              1460 non-null   int64
#  44  2ndFlrSF              1460 non-null   int64
#  45  LowQualFinSF          1460 non-null   int64
#  46  GrLivArea             1460 non-null   int64
#  47  BsmtFullBath          1460 non-null   int64
#  48  BsmtHalfBath          1460 non-null   int64
#  49  Bath1                 1460 non-null   int64
#  50  Bath2                 1460 non-null   int64
#  51  BedroomUpLev          1460 non-null   int64
#  52  KitchenUpLev          1460 non-null   int64
#  53  KitchenQual           1460 non-null   object
#  54  CntRmsUpLev           1460 non-null   int64
#  55  Functional            1460 non-null   object
#  56  CntFireplaces         1460 non-null   int64
#  57  QualFireplace         770 non-null    object
#  58  BasementType          1379 non-null   object
#  59  BasementYrBlt         1379 non-null   float64
#  60  BasementFinish        1379 non-null   object
#  61  BasementCars          1460 non-null   int64
#  62  BasementSqFootage     1460 non-null   int64
#  63  BasementQual          1379 non-null   object
#  64  BasementCond          1379 non-null   object
#  65  PavedDrive            1460 non-null   object
#  66  WoodDeckSF            1460 non-null   int64
#  67  OpenPorchSF           1460 non-null   int64
#  68  EnclosedPorch         1460 non-null   int64
#  69  3SsnPorch             1460 non-null   int64
#  70  ScreenPorch           1460 non-null   int64
#  71  PoolArea              1460 non-null   int64
#  72  PoolQC                7 non-null      object
#  73  BoundaryFeatures      281 non-null    object
#  74  AddFeatures           54 non-null     object
#  75  AddVal                1460 non-null   int64
#  76  SaleMon               1460 non-null   int64
#  77  SaleYr                1460 non-null   int64
#  78  SaleType              1460 non-null   object
#  79  SaleCondn             1460 non-null   object
#  80  PropPrice             1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# ## In the given property dataframe 35 columns have integer values and 43 are object type

# %%
# To check null values 
df.isnull()
# Out:
#       PropertyID  PropertyClass  PropertyZone  PropertyFrontage  PropertySize  \
# 0          False          False         False             False         False
# 1          False          False         False             False         False
# 2          False          False         False             False         False
# 3          False          False         False             False         False
# 4          False          False         False             False         False
# ...          ...            ...           ...               ...           ...
# 1455       False          False         False             False         False
# 1456       False          False         False             False         False
# 1457       False          False         False             False         False
# 1458       False          False         False             False         False
# 1459       False          False         False             False         False
#
#       Street  Alley  PropertyShape  Elevation  Amenities  ...  PoolArea  \
# 0      False   True          False      False      False  ...     False
# 1      False   True          False      False      False  ...     False
# 2      False   True          False      False      False  ...     False
# 3      False   True          False      False      False  ...     False
# 4      False   True          False      False      False  ...     False
# ...      ...    ...            ...        ...        ...  ...       ...
# 1455   False   True          False      False      False  ...     False
# 1456   False   True          False      False      False  ...     False
# 1457   False   True          False      False      False  ...     False
# 1458   False   True          False      False      False  ...     False
# 1459   False   True          False      False      False  ...     False
#
#       PoolQC  BoundaryFeatures  AddFeatures  AddVal  SaleMon  SaleYr  \
# 0       True              True         True   False    False   False
# 1       True              True         True   False    False   False
# 2       True              True         True   False    False   False
# 3       True              True         True   False    False   False
# 4       True              True         True   False    False   False
# ...      ...               ...          ...     ...      ...     ...
# 1455    True              True         True   False    False   False
# 1456    True             False         True   False    False   False
# 1457    True             False        False   False    False   False
# 1458    True              True         True   False    False   False
# 1459    True              True         True   False    False   False
#
#       SaleType  SaleCondn  PropPrice
# 0        False      False      False
# 1        False      False      False
# 2        False      False      False
# 3        False      False      False
# 4        False      False      False
# ...        ...        ...        ...
# 1455     False      False      False
# 1456     False      False      False
# 1457     False      False      False
# 1458     False      False      False
# 1459     False      False      False
#
# [1460 rows x 81 columns]

# %%
# To count number of null values any column has
df.isnull().sum()
# Out:
# PropertyID            0
# PropertyClass         0
# PropertyZone          0
# PropertyFrontage    259
# PropertySize          0
#                    ...
# SaleMon               0
# SaleYr                0
# SaleType              0
# SaleCondn             0
# PropPrice             0
# Length: 81, dtype: int64

# %%
# To remove null values from a columns using fillna 
df['PropertyFrontage'] = df['PropertyFrontage'].fillna(df['PropertyFrontage'].mean())

# %%
df.isnull().sum()
# Out:
# PropertyID          0
# PropertyClass       0
# PropertyZone        0
# PropertyFrontage    0
# PropertySize        0
#                    ..
# SaleMon             0
# SaleYr              0
# SaleType            0
# SaleCondn           0
# PropPrice           0
# Length: 81, dtype: int64

# %%
df.shape
# Out:
# (1460, 81)

# %%
# Remove rows that have less than a certain number of non-null values
df = df.dropna(thresh=2)

# %%
df.shape
# Out:
# (1460, 81)

# %%
# Remove columns that have NAN values more than 50 percent of the total rows
threshold = 0.5 * len(df)
df = df.loc[:, df.isnull().sum() <= threshold]

# %%
df.shape
# Out:
# (1460, 76)

# %% [markdown]
# ## Univariate Analysis

# %%
sns.countplot(x=df['PropertyZone'],hue=df['Street'])
# Out:
# <Axes: xlabel='PropertyZone', ylabel='count'>

# %%
sns.countplot(x=df['Street'])
plt.show()

# %%
sns.countplot(x=df['PropertyShape'])
# Out:
# <Axes: xlabel='PropertyShape', ylabel='count'>

# %%
sns.countplot(x=df['SaleCondn'])
# Out:
# <Axes: xlabel='SaleCondn', ylabel='count'>

# %%
# to check any outliers in a column
df['PropertyClass'].plot(kind='box')
# Out:
# <Axes: >

# %%
sns.displot(df['PropertyClass'], kde = False, color ='blue', bins = 30)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['PropertyClass'].mean()
# Out:
# 56.897260273972606

# %%
df['PropertyClass'].std()
# Out:
# 42.30057099381035

# %%
df['PropertyClass'] > (df['PropertyClass'].mean() +3 *df['PropertyClass'].std())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: PropertyClass, Length: 1460, dtype: bool

# %%
upper_bound = df['PropertyClass'].mean() + 3 * df['PropertyClass'].std()

# %%
outlier = df[df['PropertyClass'] > upper_bound]

# %%
outlier
# Out:
#       PropertyID  PropertyClass PropertyZone  PropertyFrontage  PropertySize  \
# 9             10            190           RL         50.000000          7420
# 48            49            190           RM         33.000000          4456
# 93            94            190      C (all)         60.000000          7200
# 125          126            190           RM         60.000000          6780
# 165          166            190           RL         62.000000         10106
# 246          247            190           RM         69.000000          9142
# 291          292            190           RL         55.000000          5687
# 300          301            190           RL         90.000000         15750
# 312          313            190           RM         65.000000          7800
# 335          336            190           RL         70.049958        164660
# 411          412            190           RL        100.000000         34650
# 488          489            190           RL         60.000000         10800
# 520          521            190           RL         60.000000         10800
# 535          536            190           RL         70.000000          7000
# 635          636            190           RH         60.000000         10896
# 637          638            190           RM         50.000000          6000
# 703          704            190           RM         76.000000          7630
# 705          706            190           RM         70.000000          5600
# 713          714            190           RL         60.000000          9873
# 861          862            190           RL         75.000000         11625
# 969          970            190           RL         75.000000         10382
# 985          986            190           RL         68.000000         10880
# 1030        1031            190           RH         70.049958          7082
# 1062        1063            190           RM         85.000000         13600
# 1144        1145            190           RL         60.000000         12180
# 1186        1187            190           RL        107.000000         10615
# 1190        1191            190           RL         70.049958         32463
# 1266        1267            190           RM         60.000000         10120
# 1393        1394            190           RM         60.000000         10800
# 1416        1417            190           RM         60.000000         11340
#
#      Street PropertyShape Elevation Amenities Orientation  ... EnclosedPorch  \
# 9      Pave           Reg       Lvl    AllPub      Corner  ...             0
# 48     Pave           Reg       Lvl    AllPub      Inside  ...           102
# 93     Pave           Reg       Lvl    AllPub      Corner  ...             0
# 125    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 165    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 246    Pave           Reg       Lvl    AllPub      Inside  ...           112
# 291    Pave           Reg       Bnk    AllPub      Inside  ...             0
# 300    Pave           Reg       Lvl    AllPub      Corner  ...             0
# 312    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 335    Grvl           IR1       HLS    AllPub      Corner  ...             0
# 411    Pave           Reg       Bnk    AllPub      Inside  ...             0
# 488    Pave           Reg       Lvl    AllPub      Corner  ...             0
# 520    Pave           Reg       Lvl    AllPub      Inside  ...           210
# 535    Pave           Reg       Lvl    AllPub      Inside  ...           148
# 635    Pave           Reg       Bnk    AllPub      Inside  ...             0
# 637    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 703    Pave           Reg       Lvl    AllPub      Inside  ...            40
# 705    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 713    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 861    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 969    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 985    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 1030   Pave           Reg       Lvl    AllPub      Inside  ...           228
# 1062   Pave           Reg       Lvl    AllPub      Inside  ...             0
# 1144   Pave           Reg       Lvl    AllPub      Inside  ...             0
# 1186   Pave           IR1       Bnk    AllPub      Corner  ...             0
# 1190   Pave           Reg       Low    AllPub      Inside  ...             0
# 1266   Pave           IR1       Bnk    AllPub      Inside  ...           264
# 1393   Pave           Reg       Lvl    AllPub      Inside  ...           212
# 1416   Pave           Reg       Lvl    AllPub      Inside  ...           114
#
#      3SsnPorch ScreenPorch PoolArea AddVal SaleMon  SaleYr  SaleType  \
# 9            0           0        0      0       1    2008        WD
# 48           0           0        0      0       6    2009       New
# 93           0          99        0      0      11    2007        WD
# 125          0           0        0      0       6    2006        WD
# 165          0           0        0      0       9    2008        WD
# 246          0           0        0      0       4    2006        WD
# 291          0           0        0      0       3    2008        WD
# 300          0           0        0      0       6    2006        WD
# 312          0         271        0      0       5    2006        WD
# 335          0           0        0    700       8    2008        WD
# 411          0           0        0      0       1    2006        WD
# 488          0           0        0      0       5    2006     ConLD
# 520          0           0        0      0       8    2008        WD
# 535          0           0        0      0       1    2008        WD
# 635          0           0        0      0       3    2007        WD
# 637          0           0        0      0      11    2009        WD
# 703          0           0        0      0       5    2010        WD
# 705          0           0        0   3500       7    2010        WD
# 713          0           0        0      0       5    2006        WD
# 861          0           0        0      0       4    2010        WD
# 969          0           0        0      0       3    2006     ConLD
# 985          0           0        0      0       8    2008     ConLD
# 1030         0           0        0      0       7    2006        WD
# 1062         0           0        0      0       9    2007        WD
# 1144         0           0        0      0       7    2010        WD
# 1186         0           0        0      0       8    2009        WD
# 1190         0           0        0      0       3    2007        WD
# 1266         0           0        0      0       1    2007        WD
# 1393         0           0        0      0       4    2008        WD
# 1416         0           0        0      0       4    2010        WD
#
#       SaleCondn  PropPrice
# 9        Normal     118000
# 48      Partial     113000
# 93       Normal     133900
# 125      Normal      84500
# 165      Normal     127500
# 246      Normal     137000
# 291      Normal     135900
# 300      Normal     157000
# 312      Normal     119900
# 335      Normal     228950
# 411      Normal     145000
# 488      Normal     160000
# 520      Normal     106250
# 535      Normal     107500
# 635     Abnorml     200000
# 637      Normal      93000
# 703      Normal     140000
# 705      Normal      55000
# 713      Normal     129000
# 861      Normal     131500
# 969      Normal     140000
# 985      Normal     125000
# 1030     Normal     160000
# 1062     Normal      90000
# 1144     Normal      80000
# 1186    Abnorml      95000
# 1190     Normal     168000
# 1266     Normal     122000
# 1393     Normal     163000
# 1416     Normal     122500
#
# [30 rows x 76 columns]

# %%
z_scores = (df['PropertyClass'] - df['PropertyClass'].mean()) / df['PropertyClass'].std()

# %%
z_scores
# Out:
# 0       0.073350
# 1      -0.872264
# 2       0.073350
# 3       0.309753
# 4       0.073350
#           ...
# 1455    0.073350
# 1456   -0.872264
# 1457    0.309753
# 1458   -0.872264
# 1459   -0.872264
# Name: PropertyClass, Length: 1460, dtype: float64

# %% [markdown]
# ## another method to know a outlier

# %%
outliers = df[(z_scores > 3) | (z_scores < -3)]

# %%
outliers
# Out:
#       PropertyID  PropertyClass PropertyZone  PropertyFrontage  PropertySize  \
# 9             10            190           RL         50.000000          7420
# 48            49            190           RM         33.000000          4456
# 93            94            190      C (all)         60.000000          7200
# 125          126            190           RM         60.000000          6780
# 165          166            190           RL         62.000000         10106
# 246          247            190           RM         69.000000          9142
# 291          292            190           RL         55.000000          5687
# 300          301            190           RL         90.000000         15750
# 312          313            190           RM         65.000000          7800
# 335          336            190           RL         70.049958        164660
# 411          412            190           RL        100.000000         34650
# 488          489            190           RL         60.000000         10800
# 520          521            190           RL         60.000000         10800
# 535          536            190           RL         70.000000          7000
# 635          636            190           RH         60.000000         10896
# 637          638            190           RM         50.000000          6000
# 703          704            190           RM         76.000000          7630
# 705          706            190           RM         70.000000          5600
# 713          714            190           RL         60.000000          9873
# 861          862            190           RL         75.000000         11625
# 969          970            190           RL         75.000000         10382
# 985          986            190           RL         68.000000         10880
# 1030        1031            190           RH         70.049958          7082
# 1062        1063            190           RM         85.000000         13600
# 1144        1145            190           RL         60.000000         12180
# 1186        1187            190           RL        107.000000         10615
# 1190        1191            190           RL         70.049958         32463
# 1266        1267            190           RM         60.000000         10120
# 1393        1394            190           RM         60.000000         10800
# 1416        1417            190           RM         60.000000         11340
#
#      Street PropertyShape Elevation Amenities Orientation  ... EnclosedPorch  \
# 9      Pave           Reg       Lvl    AllPub      Corner  ...             0
# 48     Pave           Reg       Lvl    AllPub      Inside  ...           102
# 93     Pave           Reg       Lvl    AllPub      Corner  ...             0
# 125    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 165    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 246    Pave           Reg       Lvl    AllPub      Inside  ...           112
# 291    Pave           Reg       Bnk    AllPub      Inside  ...             0
# 300    Pave           Reg       Lvl    AllPub      Corner  ...             0
# 312    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 335    Grvl           IR1       HLS    AllPub      Corner  ...             0
# 411    Pave           Reg       Bnk    AllPub      Inside  ...             0
# 488    Pave           Reg       Lvl    AllPub      Corner  ...             0
# 520    Pave           Reg       Lvl    AllPub      Inside  ...           210
# 535    Pave           Reg       Lvl    AllPub      Inside  ...           148
# 635    Pave           Reg       Bnk    AllPub      Inside  ...             0
# 637    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 703    Pave           Reg       Lvl    AllPub      Inside  ...            40
# 705    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 713    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 861    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 969    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 985    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 1030   Pave           Reg       Lvl    AllPub      Inside  ...           228
# 1062   Pave           Reg       Lvl    AllPub      Inside  ...             0
# 1144   Pave           Reg       Lvl    AllPub      Inside  ...             0
# 1186   Pave           IR1       Bnk    AllPub      Corner  ...             0
# 1190   Pave           Reg       Low    AllPub      Inside  ...             0
# 1266   Pave           IR1       Bnk    AllPub      Inside  ...           264
# 1393   Pave           Reg       Lvl    AllPub      Inside  ...           212
# 1416   Pave           Reg       Lvl    AllPub      Inside  ...           114
#
#      3SsnPorch ScreenPorch PoolArea AddVal SaleMon  SaleYr  SaleType  \
# 9            0           0        0      0       1    2008        WD
# 48           0           0        0      0       6    2009       New
# 93           0          99        0      0      11    2007        WD
# 125          0           0        0      0       6    2006        WD
# 165          0           0        0      0       9    2008        WD
# 246          0           0        0      0       4    2006        WD
# 291          0           0        0      0       3    2008        WD
# 300          0           0        0      0       6    2006        WD
# 312          0         271        0      0       5    2006        WD
# 335          0           0        0    700       8    2008        WD
# 411          0           0        0      0       1    2006        WD
# 488          0           0        0      0       5    2006     ConLD
# 520          0           0        0      0       8    2008        WD
# 535          0           0        0      0       1    2008        WD
# 635          0           0        0      0       3    2007        WD
# 637          0           0        0      0      11    2009        WD
# 703          0           0        0      0       5    2010        WD
# 705          0           0        0   3500       7    2010        WD
# 713          0           0        0      0       5    2006        WD
# 861          0           0        0      0       4    2010        WD
# 969          0           0        0      0       3    2006     ConLD
# 985          0           0        0      0       8    2008     ConLD
# 1030         0           0        0      0       7    2006        WD
# 1062         0           0        0      0       9    2007        WD
# 1144         0           0        0      0       7    2010        WD
# 1186         0           0        0      0       8    2009        WD
# 1190         0           0        0      0       3    2007        WD
# 1266         0           0        0      0       1    2007        WD
# 1393         0           0        0      0       4    2008        WD
# 1416         0           0        0      0       4    2010        WD
#
#       SaleCondn  PropPrice
# 9        Normal     118000
# 48      Partial     113000
# 93       Normal     133900
# 125      Normal      84500
# 165      Normal     127500
# 246      Normal     137000
# 291      Normal     135900
# 300      Normal     157000
# 312      Normal     119900
# 335      Normal     228950
# 411      Normal     145000
# 488      Normal     160000
# 520      Normal     106250
# 535      Normal     107500
# 635     Abnorml     200000
# 637      Normal      93000
# 703      Normal     140000
# 705      Normal      55000
# 713      Normal     129000
# 861      Normal     131500
# 969      Normal     140000
# 985      Normal     125000
# 1030     Normal     160000
# 1062     Normal      90000
# 1144     Normal      80000
# 1186    Abnorml      95000
# 1190     Normal     168000
# 1266     Normal     122000
# 1393     Normal     163000
# 1416     Normal     122500
#
# [30 rows x 76 columns]

# %%
df['PropertyZone'].value_counts()
# Out:
# PropertyZone
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64

# %%
df['PropertyFrontage'].plot(kind='box')
# Out:
# <Axes: >

# %%
sns.displot(df['PropertyFrontage'], kde = True, color ='red', bins = 30)
plt.show()
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['PropertyFrontage'].mean()
# Out:
# 70.04995836802664

# %%
df['PropertyFrontage'].std()
# Out:
# 22.024022688706943

# %%
upper_bound = (df['PropertyFrontage'].mean() +3 *df['PropertyFrontage'].std())

# %%
outliers=df['PropertyFrontage'] > upper_bound

# %%
outliers
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: PropertyFrontage, Length: 1460, dtype: bool

# %%
outliers=df[df['PropertyFrontage'] > upper_bound]

# %%
outliers
# Out:
#       PropertyID  PropertyClass PropertyZone  PropertyFrontage  PropertySize  \
# 171          172             20           RL             141.0         31770
# 197          198             75           RL             174.0         25419
# 231          232             60           RL             174.0         15138
# 277          278             20           RL             140.0         19138
# 313          314             20           RL             150.0        215245
# 446          447             20           RL             137.0         16492
# 807          808             70           RL             144.0         21384
# 909          910             60           RL             149.0         12589
# 934          935             20           RL             313.0         27650
# 1107        1108             60           RL             168.0         23257
# 1127        1128             20           RL             182.0         14572
# 1173        1174             50           RL             138.0         18030
# 1182        1183             60           RL             160.0         15623
# 1211        1212             50           RL             152.0         12134
# 1298        1299             60           RL             313.0         63887
# 1337        1338             30           RM             153.0          4118
#
#      Street PropertyShape Elevation Amenities Orientation  ... EnclosedPorch  \
# 171    Pave           IR1       Lvl    AllPub      Corner  ...             0
# 197    Pave           Reg       Lvl    AllPub      Corner  ...           552
# 231    Pave           IR1       Lvl    AllPub      Inside  ...           202
# 277    Pave           Reg       Lvl    AllPub      Corner  ...             0
# 313    Pave           IR3       Low    AllPub      Inside  ...             0
# 446    Pave           IR1       Lvl    AllPub      Corner  ...             0
# 807    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 909    Pave           IR2       Lvl    AllPub      Inside  ...             0
# 934    Pave           IR2       HLS    AllPub      Inside  ...             0
# 1107   Pave           IR3       HLS    AllPub     CulDSac  ...             0
# 1127   Pave           IR3       Lvl    AllPub      Corner  ...             0
# 1173   Pave           IR1       Bnk    AllPub      Inside  ...             0
# 1182   Pave           IR1       Lvl    AllPub      Corner  ...             0
# 1211   Pave           IR1       Bnk    AllPub      Inside  ...             0
# 1298   Pave           IR3       Bnk    AllPub      Corner  ...             0
# 1337   Pave           IR1       Bnk    AllPub      Corner  ...             0
#
#      3SsnPorch ScreenPorch PoolArea AddVal SaleMon  SaleYr  SaleType  \
# 171          0           0        0      0       5    2010        WD
# 197          0           0      512      0       3    2006        WD
# 231          0           0        0      0       7    2009        WD
# 277          0           0        0      0       6    2010        WD
# 313          0           0        0      0       6    2009        WD
# 446          0           0        0      0       6    2010        WD
# 807          0           0        0      0       5    2009        WD
# 909          0           0        0      0       6    2009        WD
# 934          0           0        0      0      11    2008        WD
# 1107         0           0        0      0       9    2006       New
# 1127         0           0        0      0      11    2007        WD
# 1173         0           0        0      0       3    2007        WD
# 1182         0           0      555      0       7    2007        WD
# 1211         0           0        0      0       6    2010        WD
# 1298         0           0      480      0       1    2008       New
# 1337         0           0        0      0       3    2006        WD
#
#       SaleCondn  PropPrice
# 171      Normal     215000
# 197     Abnorml     235000
# 231      Normal     403000
# 277      Normal     141000
# 313      Normal     375000
# 446      Normal     190000
# 807      Normal     223500
# 909      Normal     174000
# 934      Normal     242000
# 1107    Partial     274725
# 1127     Family     259000
# 1173     Normal     200500
# 1182    Abnorml     745000
# 1211     Normal     164000
# 1298    Partial     160000
# 1337     Normal      52500
#
# [16 rows x 76 columns]

# %%
lower_bound = (df['PropertyFrontage'].mean() - 3 *df['PropertyFrontage'].std())

# %%
outliers=df['PropertyFrontage'] < lower_bound

# %%
outliers=df[df['PropertyFrontage'] < lower_bound]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [PropertyID, PropertyClass, PropertyZone, PropertyFrontage, PropertySize, Street, PropertyShape, Elevation, Amenities, Orientation, Grade, Neighborhood, Condition1, Condition2, BldgType, PropertyStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Roof1Material, Roof2Material, ExteriorCladdingArea, ExterQual, ExterCond, PropertyFooting, BsmntFinish, BsmntMaintenance, BsmntVisibility, BsmntFinRat1, BsmntFinSty1, BsmntFinQual1, BsmtFinSF2, BsmtUnfSF, BsmntSqFtage, Heating, HeatingEfficiency, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, Bath1, Bath2, BedroomUpLev, KitchenUpLev, KitchenQual, CntRmsUpLev, Functional, CntFireplaces, QualFireplace, BasementType, BasementYrBlt, BasementFinish, BasementCars, BasementSqFootage, BasementQual, BasementCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, AddVal, SaleMon, SaleYr, SaleType, SaleCondn, PropPrice]
# Index: []
#
# [0 rows x 76 columns]

# %%
z_scores = (df['PropertyFrontage'] - df['PropertyFrontage'].mean()) / df['PropertyFrontage'].std()

# %%
outliers = df[(z_scores > 3) | (z_scores < -3)]

# %%
outliers
# Out:
#       PropertyID  PropertyClass PropertyZone  PropertyFrontage  PropertySize  \
# 171          172             20           RL             141.0         31770
# 197          198             75           RL             174.0         25419
# 231          232             60           RL             174.0         15138
# 277          278             20           RL             140.0         19138
# 313          314             20           RL             150.0        215245
# 446          447             20           RL             137.0         16492
# 807          808             70           RL             144.0         21384
# 909          910             60           RL             149.0         12589
# 934          935             20           RL             313.0         27650
# 1107        1108             60           RL             168.0         23257
# 1127        1128             20           RL             182.0         14572
# 1173        1174             50           RL             138.0         18030
# 1182        1183             60           RL             160.0         15623
# 1211        1212             50           RL             152.0         12134
# 1298        1299             60           RL             313.0         63887
# 1337        1338             30           RM             153.0          4118
#
#      Street PropertyShape Elevation Amenities Orientation  ... EnclosedPorch  \
# 171    Pave           IR1       Lvl    AllPub      Corner  ...             0
# 197    Pave           Reg       Lvl    AllPub      Corner  ...           552
# 231    Pave           IR1       Lvl    AllPub      Inside  ...           202
# 277    Pave           Reg       Lvl    AllPub      Corner  ...             0
# 313    Pave           IR3       Low    AllPub      Inside  ...             0
# 446    Pave           IR1       Lvl    AllPub      Corner  ...             0
# 807    Pave           Reg       Lvl    AllPub      Inside  ...             0
# 909    Pave           IR2       Lvl    AllPub      Inside  ...             0
# 934    Pave           IR2       HLS    AllPub      Inside  ...             0
# 1107   Pave           IR3       HLS    AllPub     CulDSac  ...             0
# 1127   Pave           IR3       Lvl    AllPub      Corner  ...             0
# 1173   Pave           IR1       Bnk    AllPub      Inside  ...             0
# 1182   Pave           IR1       Lvl    AllPub      Corner  ...             0
# 1211   Pave           IR1       Bnk    AllPub      Inside  ...             0
# 1298   Pave           IR3       Bnk    AllPub      Corner  ...             0
# 1337   Pave           IR1       Bnk    AllPub      Corner  ...             0
#
#      3SsnPorch ScreenPorch PoolArea AddVal SaleMon  SaleYr  SaleType  \
# 171          0           0        0      0       5    2010        WD
# 197          0           0      512      0       3    2006        WD
# 231          0           0        0      0       7    2009        WD
# 277          0           0        0      0       6    2010        WD
# 313          0           0        0      0       6    2009        WD
# 446          0           0        0      0       6    2010        WD
# 807          0           0        0      0       5    2009        WD
# 909          0           0        0      0       6    2009        WD
# 934          0           0        0      0      11    2008        WD
# 1107         0           0        0      0       9    2006       New
# 1127         0           0        0      0      11    2007        WD
# 1173         0           0        0      0       3    2007        WD
# 1182         0           0      555      0       7    2007        WD
# 1211         0           0        0      0       6    2010        WD
# 1298         0           0      480      0       1    2008       New
# 1337         0           0        0      0       3    2006        WD
#
#       SaleCondn  PropPrice
# 171      Normal     215000
# 197     Abnorml     235000
# 231      Normal     403000
# 277      Normal     141000
# 313      Normal     375000
# 446      Normal     190000
# 807      Normal     223500
# 909      Normal     174000
# 934      Normal     242000
# 1107    Partial     274725
# 1127     Family     259000
# 1173     Normal     200500
# 1182    Abnorml     745000
# 1211     Normal     164000
# 1298    Partial     160000
# 1337     Normal      52500
#
# [16 rows x 76 columns]

# %%
sns.displot(df['PropertySize'],kde=True,bins=30)
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df['PropertySize'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Street'].value_counts()
# Out:
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
